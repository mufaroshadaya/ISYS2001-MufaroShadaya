# %% [markdown]
# <a href="https://colab.research.google.com/github/mufaroshadaya/ISYS2001-MufaroShadaya/blob/main/Module%2004%20-%20Going%20Loopy/week4_financial_tracker_MufaroShadaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Workshop 1: Loop Fundamentals
# ## Building Repetition Into Your Finance Tracker
#
# **Duration:** 45 minutes
# **Goal:** Master the core patterns of repetition in programming through financial scenarios
#
# ### What You'll Build
# By the end of this workshop, your finance tracker will handle:
# - ✅ Multiple expense entries in one session
# - ✅ Smart input validation that keeps asking until valid
# - ✅ Running totals and budget tracking
# - ✅ User-controlled program flow (menus that loop)
#
# ---

# %% [markdown]
# ## Part 1: Design Before Code (10 minutes)
#
# ### 🧠 Computational Thinking Exercise
#
# Before writing any loops, let's think through the patterns you'll need:
#
# **Scenario:** You want to track a week's worth of expenses, but you don't know how many transactions you'll have each day.
#
# #### Your Design Challenge
# In the cell below, write pseudocode (plain English) for how you'd handle this:
#
# ```
# Example pseudocode:
# 1. Ask user how many expenses they have
# 2. For each expense...
# 3. Validate the input...
# 4. Calculate running total...
# ```

# %%
# Start
#1. Ask the user how many expenses they want to enter.
# 2. Set a variable called running_total to 0 to store the total amount of expenses.
# 3. Repeat the following steps for the number of expenses entered by the user:
#    - Ask the user to enter the expense amount.
# 4. Check if the entered amount is valid (a number not negative).
#    - If the amount is invalid, show an error message and ask the user to enter the amount again.
# 5. If the amount is valid, add it to the running_total and show the updated total to the user.
# 6. After all expenses are entered, display the final total of all expenses.

# %% [markdown]
# ### 🤝 AI Checkpoint 1: Design Review
#
# Once you've written your pseudocode, copy it and ask AI:
#
# ```
# "I'm learning loops in Python. Here's my pseudocode for tracking multiple expenses:
# # Start
# # 1. Ask the user how many expenses they want to enter.
# # 2. Set a variable called running_total to 0 to store the total amount of expenses.
# # 3. Repeat the following steps for the number of expenses entered by the user:
# #    - Ask the user to enter the expense amount.
# # 4. Check if the entered amount is valid (a number and not negative).
# #    - If the amount is invalid, show an error message and ask the user to enter the amount again.
# # 5. If the amount is valid, add it to the running_total and show the updated total to the user.
# # 6. After all expenses are entered, display the final total of all expenses.
#
# Use both loops together:
# for loop - repeat for each expense
# while loop - make sure the entered value is valid
# ```
#
# **Reflect:**
# Repeating for each expense
# You ask for an expense amount multiple times.
# Each time you add it to the running total.
# Repeating when input is invalid
# If the user enters something invalid (not a number or negative), you ask again until it is correct.
# ---

# %% [markdown]
# ## Part 2: While Loops for Validation (15 minutes)
#
# ### 🛡️ Smart Input Validation
#
# Your finance tracker needs to handle invalid inputs gracefully. Let's start with the most important validation pattern:

# %%
# Example: Keep asking until valid dollar amount
print("=== Expense Entry with Validation ===")

# We'll ask for an expense amount and keep asking until it's valid
expense = -1  # Start with invalid value

while expense < 0:  # Keep going while invalid
    try:
        expense_str = input("Enter expense amount: $")
        expense = float(expense_str)

        if expense < 0:
            print("Expense cannot be negative! Try again.")
    except ValueError:
        print("Please enter a valid number!")
        expense = -1  # Keep loop going

print(f"Valid expense recorded: ${expense:.2f}")

# %% [markdown]
# ### 🎯 Your Challenge: Budget Validation
#
# Extend the validation pattern above for monthly budget entry. Your budget should be:
# - A positive number
# - At least $100 (reasonable minimum)
# - No more than $50,000 (reasonable maximum)
#
# **Think first:** What condition should your while loop check?

# %%
print("=== Monthly Budget Entry ===")

budget = 0  # Starting with an invalid value

# Keep looping while budget is outside the valid range
while budget < 100 or budget > 50000:
    try:
        budget_str = input("Enter monthly budget ($100-$50,000): $")
        budget = float(budget_str)

        # Validation check
        if budget < 100 or budget > 50000:
            print("Budget must be between $100 and $50,000.")

    except ValueError:
        print("Please enter a valid number!")
        budget = 0  # Keep loop going

print(f"Budget set to: ${budget:.2f}")
# Out:
# === Monthly Budget Entry ===
# Enter monthly budget ($100-$50,000): $-1
# Budget must be between $100 and $50,000.
# Enter monthly budget ($100-$50,000): $99.0
# Budget must be between $100 and $50,000.
# Enter monthly budget ($100-$50,000): $99.9
# Budget must be between $100 and $50,000.
# Enter monthly budget ($100-$50,000): $55670
# Budget must be between $100 and $50,000.
# Enter monthly budget ($100-$50,000): $329
# Budget set to: $329.00

# %% [markdown]
# ### 💡 Pattern Recognition
#
# Notice the validation pattern:
# 1. **Initialize** with invalid value
# 2. **Loop while** condition is invalid
# 3. **Get input** inside loop
# 4. **Validate** and give feedback
# 5. **Update** variable to potentially exit loop
#
# This pattern works for ANY validation scenario!

# %% [markdown]
# ---
#
# ## Part 3: Sentinel Values for Unknown Repetition (10 minutes)
#
# ### 🏁 The "Done" Pattern
#
# Sometimes you don't know how many times to repeat. You need a **sentinel value** - a special input that means "stop".

# %%
# Example: Collect expenses until user says "done"
print("=== Multiple Expense Entry ===")

expenses = []  # List to store all expenses
total = 0      # Running total

print("Enter your expenses (type 'done' when finished):")

while True:  # Infinite loop - we'll break out when ready
    expense_input = input("Expense amount (or 'done'): $")

    # Check if user wants to stop
    if expense_input.lower() == 'done':
        break  # Exit the loop

    # Try to convert to number
    try:
        expense = float(expense_input)
        if expense >= 0:
            expenses.append(expense)
            total += expense
            print(f"  Added ${expense:.2f} | Running total: ${total:.2f}")
        else:
            print("  Expense must be positive!")
    except ValueError:
        print("  Please enter a valid number or 'done'")

print(f"\n📊 Summary: {len(expenses)} expenses totaling ${total:.2f}")

# %% [markdown]
# ### 🎯 Your Challenge: Category Entry
#
# Build a system that collects expense categories until the user enters "finish":
# - Ask for category names
# - Don't allow empty categories
# - Show count after each entry
# - Stop when user types "finish"

# %%
print("=== Expense Categories Entry ===")

categories = []
count = 0

while True:
    category = input("Enter an expense category (or type 'finish' to stop): ").strip()

    # Stop condition
    if category.lower() == "finish":
        break

    # Validation: prevent empty input
    if category == "":
        print("Category cannot be empty. Please enter a valid category.")
    else:
      categories.append(category)
      print(f"Category added. Current total is: {len(categories)} ")
      print(f"Category '{category}' added.")

    # Count valid category
    count += 1

print("\nCategories entered:", categories)
print(f"\nYou entered {count} expense categories.")
# Out:
# === Expense Categories Entry ===
# Enter an expense category (or type 'finish' to stop): food
# Category added. Current total is: 1
# Category 'food' added.
# Enter an expense category (or type 'finish' to stop): transport
# Category added. Current total is: 2
# Category 'transport' added.
# Enter an expense category (or type 'finish' to stop): parties
# Category added. Current total is: 3
# Category 'parties' added.
# Enter an expense category (or type 'finish' to stop): finish
#
# Categories entered: ['food', 'transport', 'parties']
#
# You entered 3 expense categories.

# %% [markdown]
# ---
#
# ## Part 4: For Loops with Known Counts (10 minutes)
#
# ### 📅 Weekly Expense Planning
#
# Sometimes you know exactly how many items you need. Perfect for `for` loops!

# %%
# Example: Get expenses for each day of the work week
print("=== Weekly Expense Planner ===")

days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
weekly_expenses = []
total_week = 0

print("Plan your expenses for each workday:")

for day in days:
    # Get planned expense for this day
    while True:  # Validation loop inside for loop!
        try:
            expense_str = input(f"{day} planned expense: $")
            expense = float(expense_str)
            if expense >= 0:
                weekly_expenses.append(expense)
                total_week += expense
                break  # Valid input, exit validation loop
            else:
                print("  Expense must be non-negative")
        except ValueError:
            print("  Please enter a valid number")

print(f"\n📅 Weekly Plan: ${total_week:.2f} total")
print(f"📊 Daily average: ${total_week/len(days):.2f}")

# %% [markdown]
# ### 🎯 Your Challenge: Savings Goals
#
# Create a system that tracks progress on exactly 3 savings goals:
# - Ask for goal name and target amount for each goal
# - Ask for current progress on each goal
# - Calculate and display percentage complete for each
# - Use `range(3)` to control the loop

# %%
# Your savings goals tracker here
print("=== Savings Goals Tracker ===")

goals = []  # Will store dictionaries with goal info

print("Let's set up 3 savings goals:")

# Your for loop with range(3) here
for i in range(3):
    print(f"\nGoal {i+1}")

# For each goal, ask for: name, target amount, current amount
    goal_name = input("Enter the goal name: ")
    target_amount = float(input("Enter the target amount: $"))
    current_progress = float(input("Enter the current amount saved: $"))

# Calculate percentage and store goal info
    percentage = (current_progress / target_amount) * 100

# Display summary of all goals
    print(f"{goal_name} is {percentage:.2f}% complete.")
# Out:
# === Savings Goals Tracker ===
# Let's set up 3 savings goals:
#
# Goal 1
# Enter the goal name: holiday
# Enter the target amount: $500
# Enter the current amount saved: $390
# holiday is 78.00% complete.
#
# Goal 2
# Enter the goal name: car
# Enter the target amount: $2000
# Enter the current amount saved: $1239
# car is 61.95% complete.
#
# Goal 3
# Enter the goal name: school
# Enter the target amount: $20000
# Enter the current amount saved: $14500
# school is 72.50% complete.

# %% [markdown]
# ---
#
# ## Part 5: Building Your Enhanced Finance Tracker (10 minutes)
#
# ### 🚀 Integration Challenge
#
# Now combine everything you've learned to enhance your Week 2 finance tracker. Your enhanced version should:
#
# 1. **Setup Phase**: Get user info with validation
# 2. **Transaction Loop**: Allow multiple expense entries
# 3. **Analysis**: Process all transactions for insights
# 4. **Menu System**: Keep running until user chooses to exit
#
# **Start with this framework and complete each section:**

# %%
print("=== Enhanced Finance Tracker v0.2 ===")
print("Week 3: Now with Loop Power!")
print()

# ========== SETUP PHASE ==========
name = input("Enter your name: ")

# Get monthly budget with validation
budget = 0
while budget < 100 or budget > 50000:
    try:
        budget_input = input("Enter your monthly budget ($100-$50,000): $")
        budget = float(budget_input)

        if budget < 100 or budget > 50000:
            print("Budget must be between $100 and $50,000.")

    except ValueError:
        print("Please enter a valid number!")
        budget = 0

print(f"\nWelcome {name}! Budget: ${budget:.2f}")

# ========== TRANSACTION COLLECTION ==========
expenses = []      # Store all expenses
descriptions = []  # Store descriptions
total_spent = 0

print("\n--- Enter Your Expenses ---")
print("Type 'done' when finished")

while True:
    amount_input = input("Enter expense amount: ")

    if amount_input.lower() == "done":
        break

    try:
        amount = float(amount_input)

        if amount <= 0:
            print("Expense must be greater than 0.")
            continue

        description = input("Enter expense description: ")

        # Store data
        expenses.append(amount)
        descriptions.append(description)

        # Update total
        total_spent += amount

        # Budget feedback
        percent_used = (total_spent / budget) * 100
        print(f"Added! You have used {percent_used:.1f}% of your budget.")

    except ValueError:
        print("Please enter a valid number!")

# ========== ANALYSIS PHASE ==========
print(f"\n📊 Expense Analysis:")
print(f"Total expenses: {len(expenses)}")
print(f"Total spent: ${total_spent:.2f}")
print(f"Budget used: {(total_spent/budget)*100:.1f}%")
print(f"Remaining: ${budget - total_spent:.2f}")

# Categorize expenses by size
large_expenses = 0  # Count expenses > 10% of budget

for expense in expenses:
    if expense > (budget * 0.10):
        large_expenses += 1

print(f"Large expenses (>10% budget): {large_expenses}")

print("\n🎯 Your finance tracker is growing stronger each week!")
# Out:
# === Enhanced Finance Tracker v0.2 ===
# Week 3: Now with Loop Power!
#
# Enter your name: Mufaro Shadaya
# Enter your monthly budget ($100-$50,000): $99
# Budget must be between $100 and $50,000.
# Enter your monthly budget ($100-$50,000): $55000
# Budget must be between $100 and $50,000.
# Enter your monthly budget ($100-$50,000): $20000
#
# Welcome Mufaro Shadaya! Budget: $20000.00
#
# --- Enter Your Expenses ---
# Type 'done' when finished
# Enter expense amount: food
# Please enter a valid number!
# Enter expense amount: 300
# Enter expense description: n/a
# Added! You have used 1.5% of your budget.
# Enter expense amount: electricity
# Please enter a valid number!
# Enter expense amount: 500
# Enter expense description: upkeep
# Added! You have used 4.0% of your budget.
# Enter expense amount: car rental
# Please enter a valid number!
# Enter expense amount: 9000
# Enter expense description: accomodation
# Added! You have used 49.0% of your budget.
# Enter expense amount: done
#
# 📊 Expense Analysis:
# Total expenses: 3
# Total spent: $9800.00
# Budget used: 49.0%
# Remaining: $10200.00
# Large expenses (>10% budget): 1
#
# 🎯 Your finance tracker is growing stronger each week!

# %% [markdown]
# ### 🤝 AI Checkpoint 2: Code Review
#
# After completing your enhanced tracker, ask AI:
#
# ```
# "I've written a finance tracker using while loops for validation and sentinel values for expense collection.
# Here's my code:
# print("=== Enhanced Finance Tracker v0.2 ===")
# print("Week 3: Now with Loop Power!")
# print()
#
# # ========== SETUP PHASE ==========
# name = input("Enter your name: ")
#
# # Get monthly budget with validation
# budget = 0
# while budget < 100 or budget > 50000:
#     try:
#         budget_input = input("Enter your monthly budget ($100-$50,000): $")
#         budget = float(budget_input)
#
#         if budget < 100 or budget > 50000:
#             print("Budget must be between $100 and $50,000.")
#
#     except ValueError:
#         print("Please enter a valid number!")
#         budget = 0
#
# print(f"\nWelcome {name}! Budget: ${budget:.2f}")
#
# # ========== TRANSACTION COLLECTION ==========
# expenses = []      # Store all expenses
# descriptions = []  # Store descriptions
# total_spent = 0
#
# print("\n--- Enter Your Expenses ---")
# print("Type 'done' when finished")
#
# while True:
#     amount_input = input("Enter expense amount: ")
#
#     if amount_input.lower() == "done":
#         break
#
#     try:
#         amount = float(amount_input)
#
#         if amount <= 0:
#             print("Expense must be greater than 0.")
#             continue
#
#         description = input("Enter expense description: ")
#
#         # Store data
#         expenses.append(amount)
#         descriptions.append(description)
#
#         # Update total
#         total_spent += amount
#
#         # Budget feedback
#         percent_used = (total_spent / budget) * 100
#         print(f"Added! You have used {percent_used:.1f}% of your budget.")
#
#     except ValueError:
#         print("Please enter a valid number!")
#
# # ========== ANALYSIS PHASE ==========
# print(f"\n📊 Expense Analysis:")
# print(f"Total expenses: {len(expenses)}")
# print(f"Total spent: ${total_spent:.2f}")
# print(f"Budget used: {(total_spent/budget)*100:.1f}%")
# print(f"Remaining: ${budget - total_spent:.2f}")
#
# # Categorize expenses by size
# large_expenses = 0  # Count expenses > 10% of budget
#
# for expense in expenses:
#     if expense > (budget * 0.10):
#         large_expenses += 1
#
# print(f"Large expenses (>10% budget): {large_expenses}")
#
# print("\n🎯 Your finance tracker is growing stronger each week!")
#
# 1. Are there any common loop errors in my code?
# - there are errors in not being consistent with spelling my variables and it derailed my progress while coding
# 2. What loop patterns am I using successfully?
# - i am able to use the if and while loops without any challenges
# 3. How could I make the user experience better?
# - i feel like my code is well enough and user friendly
#
# Please explain your feedback - I want to understand, not just get fixes."
#
# The feedback helped me understand where my program could be improved. For example, I was advised to add better input validation and clearer loop structures. This feedback is important because it makes the program more reliable and prevents errors if the user enters incorrect data.
# After reviewing the feedback, I improved my code by adding validation loops to ensure the budget is within the allowed range and by using a sentinel loop so the user can enter multiple expenses until they type "done". I also added clearer output messages so the user understands what the program is doing.
# This process helped me understand how loops, validation, and lists can work together to build a more complete program.
# ```
#
# ---

# %% [markdown]
# ## Part 6: Testing and Debugging (5 minutes)
#
# ### 🐛 Common Loop Problems
#
# Test your enhanced tracker with these scenarios:
#
# 1. **Edge Case Testing:**
#    - Enter invalid budget amounts
#    - ans: I tested the program by entering budget values outside the allowed range.
#    - Try negative expenses
#    - ans: The validation loop correctly asked the user to enter a new value.
#    - Enter non-numeric values
#    - ans: I also tried entering text instead of numbers to ensure the ValueError message appeared.
#    - Type "done" immediately (zero expenses)
#    - ans: This confirmed that the program handles incorrect input safely.
#
# 2. **Realistic Testing:**
#    - Enter 5-7 normal expenses
#    - ans: entered around 6 normal expenses to simulate real usage.
#    - Mix small and large amounts
#    - ans:I mixed small and large amounts to see if the program calculated totals correctly.
#    - Use the analysis features
#    - ans: The analysis section correctly showed the total spent, remaining budget, and percentage used
#
# ### 🔍 Debugging Checklist
#
# If your loops aren't working:
# - ✅ **Infinite loop?** Check that your condition can become False
# - ✅ **Never executes?** Check your initial values
# - ✅ **Wrong number of iterations?** Trace through manually
# - ✅ **Validation not working?** Check your condition logic

# %%
# Quick debugging test - this should print 1, 2, 3, 4, 5
print("Debug test - should count 1 to 5:")

count = 1
while count <= 5:
    print(count)
    count = count + 1  # Critical: must change the variable!

print("If you see 1-5 above, your loops are working! 🎉")
# Out:
# Debug test - should count 1 to 5:
# 1
# 2
# 3
# 4
# 5
# If you see 1-5 above, your loops are working! 🎉

# %% [markdown]
# ---
#
# ## Part 7: Reflection and Next Steps (5 minutes)
#
# ### 🤔 Computational Thinking Reflection
#
# Answer these questions about your loop learning:
#
# 1. **Pattern Recognition**: What loop patterns did you use most in your finance tracker?
#
# 2. **Problem Decomposition**: How did you break down the "multiple expenses" problem into smaller loop problems?
#
# 3. **AI Partnership**: How did AI help you understand loops vs. just giving you code?
#
# 4. **Transfer Thinking**: Where else in life do you see these same repetition patterns?
#
# **Write your reflections below:**

# %%
# Your reflections (as comments):

# Your reflections (as comments):

# 1. Pattern Recognition:
# In my finance tracker, I mainly used while loops for validation and for collecting multiple expenses. The validation loop keeps asking for input until the user enters a valid budget. I also used a sentinel loop where the program keeps collecting expenses until the user types "done". These patterns helped control repetition and user input.

# 2. Problem Decomposition:
# I broke the multiple expenses problem into smaller steps. First, I created a loop that keeps asking for expenses until the user types "done". Then inside the loop I added steps to validate the amount, store the expense in a list, update the running total, and give feedback about the budget usage. Breaking the problem into smaller parts made it easier to implement.

# 3. AI Partnership:
# AI helped me understand when to use different loop types and how the conditions control the loop. Instead of only giving code, it explained why loops repeat, how sentinel values work, and how validation loops prevent incorrect input. This helped me understand the logic behind the program.

# 4. Transfer Thinking:
#These repetition patterns appear in real life in many situations. For example, tracking daily expenses, checking items on a shopping list, or processing multiple customer orders in a system. In each case, a process repeats until a condition is met, which is similar to how loops work in programming.

print("Reflection complete! 🎯")
print("Next: Workshop 2 will add lists and data processing to your tracker")

print("Reflection complete! 🎯")
print("Next: Workshop 2 will add lists and data processing to your tracker")
# Out:
# Reflection complete! 🎯
# Next: Workshop 2 will add lists and data processing to your tracker
# Reflection complete! 🎯
# Next: Workshop 2 will add lists and data processing to your tracker

# %% [markdown]
# ### 🚀 Workshop 1 Complete!
#
# **What you've mastered:**
# - ✅ While loops for input validation
# - ✅ Sentinel values for unknown repetition
# - ✅ For loops for known counts
# - ✅ Combining validation with data collection
# - ✅ Strategic AI partnership for learning
#
# **Your Enhanced Finance Tracker now:**
# - Handles multiple transactions safely
# - Validates all user input
# - Provides running totals and analysis
# - Uses robust loop patterns
#
# ### 📅 Coming Next: Workshop 2
# - Lists for storing transaction history
# - Processing collections of financial data
# - Menu systems for interactive programs
# - Advanced analysis with loop + list combinations
#
# ---
#
# ### 💾 Save Your Work!
# Your enhanced finance tracker is the foundation for Workshop 2. Save this notebook and be ready to extend it further!
#
# **Next class preparation:**
# - Review your reflection answers
# - Think about what financial insights you'd want from a list of transactions
# - Practice explaining your loop choices to AI
